# %%
import numpy as np
m = 100
X = 6*np.random.rand(m,1) - 3
y = 0.5 * X**2 + 2 + np.random.randn(m,1)

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_features = PolynomialFeatures(degree = 2,include_bias=False)
X_poly = poly_features.fit_transform(X)

# %%
X[0]
# Out:
# array([0.49498948])

# %%
X_poly[0]
# Out:
# array([0.49498948, 0.24501458, 0.12127964])

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X_poly,y)
lin_reg.intercept_, lin_reg.coef_
# Out:
# (array([1.79067417]), array([[0.02064145, 0.51877214]]))

# %%
points = np.linspace(-3,3,1000)

# %%
_y = (points**2)*lin_reg.coef_[0][1] + (points)*lin_reg.coef_[0][0] + lin_reg.intercept_

# %%
plt.scatter(X,y)
plt.plot(points,_y,"r-")
plt.show()
